# %%
from keras.datasets import imdb

# %%
(train_data,train_labels),(test_data,test_labels)=imdb.load_data(num_words=10000)

#x_test = test_data
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 18s 1us/step

# %%
train_data.shape
# Out:
# (25000,)

# %%
train_labels[0]
# Out:
# 1

# %%
word_index=imdb.get_word_index()
reverse_word_index=dict([value,key] for (key,value) in word_index.items())
decoded_review = ' '.join([reverse_word_index.get(i-3,'?') for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 13s 8us/step

# %%
decoded_review
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
#prepare the data
import numpy as np

# %%
#perform one_hot vector encoding
def vectorize(sequences,dimensions=10000):
  results = np.zeros((len(sequences),dimensions))
  for i, sequences in enumerate(sequences):
    results[i,sequences]=1
  return results

# %%
x_train=vectorize(train_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
#building the network
from keras import models
from keras import layers

# %%
model = models.Sequential()

# %%
model.add(layers.Dense(16,activation='relu',input_shape=(10000,)))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dense(1,activation = 'sigmoid'))

# %%
#compilation step 
#from keras import util.custom_object_scope
model.compile(optimizer='RMSprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#validating the approach
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

# %%
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
#fit the model
history=model.fit(partial_x_train,partial_y_train,epochs=20, batch_size=512, validation_data=(x_val,y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 23s 560ms/step - loss: 0.5318 - accuracy: 0.7761 - val_loss: 0.4404 - val_accuracy: 0.8188
# Epoch 2/20
# 30/30 [==============================] - 3s 89ms/step - loss: 0.3358 - accuracy: 0.8891 - val_loss: 0.3188 - val_accuracy: 0.8842
# Epoch 3/20
# 30/30 [==============================] - 3s 89ms/step - loss: 0.2480 - accuracy: 0.9173 - val_loss: 0.2896 - val_accuracy: 0.8838
# Epoch 4/20
# 30/30 [==============================] - 2s 82ms/step - loss: 0.1975 - accuracy: 0.9325 - val_loss: 0.2812 - val_accuracy: 0.8859
# Epoch 5/20
# 30/30 [==============================] - 3s 95ms/step - loss: 0.1655 - accuracy: 0.9454 - val_loss: 0.2993 - val_accuracy: 0.8815
# Epoch 6/20
# 30/30 [==============================] - 3s 86ms/step - loss: 0.1423 - accuracy: 0.9541 - val_loss: 0.3021 - val_accuracy: 0.8820
# Epoch 7/20
# 30/30 [==============================] - 2s 79ms/step - loss: 0.1266 - accuracy: 0.9585 - val_loss: 0.3076 - val_accuracy: 0.8792
# Epoch 8/20
# 30/30 [==============================] - 3s 114ms/step - loss: 0.1061 - accuracy: 0.9683 - val_loss: 0.3165 - val_accuracy: 0.8813
# Epoch 9/20
# 30/30 [==============================] - 2s 83ms/step - loss: 0.0911 - accuracy: 0.9731 - val_loss: 0.3257 - val_accuracy: 0.8808
# Epoch 10/20
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0817 - accuracy: 0.9767 - val_loss: 0.3391 - val_accuracy: 0.8812
# Epoch 11/20
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0668 - accuracy: 0.9828 - val_loss: 0.3629 - val_accuracy: 0.8761
# Epoch 12/20
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0601 - accuracy: 0.9851 - val_loss: 0.4718 - val_accuracy: 0.8553
# Epoch 13/20
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0535 - accuracy: 0.9877 - val_loss: 0.3947 - val_accuracy: 0.8765
# Epoch 14/20
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0435 - accuracy: 0.9907 - val_loss: 0.4246 - val_accuracy: 0.8708
# Epoch 15/20
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0369 - accuracy: 0.9932 - val_loss: 0.4380 - val_accuracy: 0.8746
# Epoch 16/20
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0311 - accuracy: 0.9948 - val_loss: 0.4901 - val_accuracy: 0.8634
# Epoch 17/20
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0324 - accuracy: 0.9928 - val_loss: 0.4838 - val_accuracy: 0.8716
# Epoch 18/20
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0214 - accuracy: 0.9969 - val_loss: 0.5140 - val_accuracy: 0.8714
# Epoch 19/20
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0212 - accuracy: 0.9962 - val_loss: 0.5272 - val_accuracy: 0.8705
# Epoch 20/20
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0150 - accuracy: 0.9989 - val_loss: 0.5644 - val_accuracy: 0.8655

# %%
history_dict = history.history

# %%
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history_dict['accuracy']
val_loss = history_dict['val_loss']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']

# %%
#plotting training and validation loss
import matplotlib.pyplot as plt
epochs = range(1, len(acc)+1)
plt.plot(epochs, loss, 'bo', label = 'training loss')
plt.plot(epochs, val_loss,'b', label = 'validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
plt.plot(epochs, acc, 'bo',label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
import numpy as np
#result = model.predict(test_data)
print(np.mean(history_dict['accuracy']))
#print(history_dict)
# Out:
# 0.9605100005865097

# %%
#Out put analysis,
#[0.9865479] is a single prediction value for a particular input sample in the test data. 
#It is the predicted probability of the positive sentiment class (class 1) for that input.
#Since the output activation function of the last layer of the model is sigmoid, which maps the predicted values to a range of [0,1]
#,the output values represent the probabilities of the positive class. 
#In this case, the probability of the positive class for the given input sample is 0.9865479, which is very close to 1, indicating that the model is highly confident in predicting the positive class for that input.
